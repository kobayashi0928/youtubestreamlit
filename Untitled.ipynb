# %%
import streamlit as st
import numpy as np
import pandas as pd

st.title('streamlit 入門')

st.write("DataFrame")

df = pd.DataFrame(
    np.random.rand(100, 2)/[50, 50] + [35.69, 139.70],
    columns = ['lat', 'lon']
)
df
# Out:
#           lat         lon
# 0   35.707609  139.712502
# 1   35.691442  139.707339
# 2   35.697341  139.704901
# 3   35.691387  139.707906
# 4   35.693570  139.705449
# ..        ...         ...
# 95  35.707241  139.701236
# 96  35.696963  139.715545
# 97  35.709260  139.703409
# 98  35.695861  139.702075
# 99  35.698602  139.700198
#
# [100 rows x 2 columns]
